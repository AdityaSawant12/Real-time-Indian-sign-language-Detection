# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\keras\src\ops\operation.py:234, in Operation.from_config(cls, config)
#     233 try:
# --> 234     return cls(**config)
#     235 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\convolutional\depthwise_conv2d.py:120, in DepthwiseConv2D.__init__(self, kernel_size, strides, padding, depth_multiplier, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, **kwargs)
#     101 def __init__(
#     102     self,
#     103     kernel_size,
#    (...)
#     118     **kwargs
#     119 ):
# --> 120     super().__init__(
#     121         rank=2,
#     122         depth_multiplier=depth_multiplier,
#     123         kernel_size=kernel_size,
# ...

# %%
from keras.models import load_model
from keras.layers import DepthwiseConv2D
import cv2  # Install opencv-python
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Custom DepthwiseConv2D to ignore the 'groups' argument if present
class CustomDepthwiseConv2D(DepthwiseConv2D):
    def __init__(self, *args, groups=1, **kwargs):
        super().__init__(*args, **kwargs)

# Load the model with custom object handling for DepthwiseConv2D
model = load_model("keras_Model.h5", custom_objects={'DepthwiseConv2D': CustomDepthwiseConv2D}, compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the model's input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predict the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name.strip(), end="")
    print(" Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Class: 8 I Confidence Score: 42 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Class: 8 I Confidence Score: 71 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Class: 8 I Confidence Score: 57 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Class: 8 I Confidence Score: 52 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Class: 8 I Confidence Score: 68 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Class: 8 I Confidence Score: 51 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Class: 8 I Confidence Score: 58 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Class: 8 I Confidence Score: 88 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Class: 8 I Confidence Score: 39 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Class: 8 I Confidence Score: 86 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Class: 8 I Confidence Score: 72 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Class: 8 I Confidence Score: 84 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Class: 6 G Confidence Score: 42 %
# ...

# %%
from keras.models import load_model
from keras.layers import DepthwiseConv2D
import cv2  # Install opencv-python
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Custom DepthwiseConv2D to ignore the 'groups' argument if present
class CustomDepthwiseConv2D(DepthwiseConv2D):
    def __init__(self, *args, groups=1, **kwargs):
        super().__init__(*args, **kwargs)

# Load the model with custom object handling for DepthwiseConv2D
model = load_model("keras_Model.h5", custom_objects={'DepthwiseConv2D': CustomDepthwiseConv2D}, compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height, 224-width) pixels
    image_resized = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Make the image a numpy array and reshape it to the model's input shape.
    image_array = np.asarray(image_resized, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image_array = (image_array / 127.5) - 1

    # Predict the model
    prediction = model.predict(image_array)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Check if confidence score is greater than 70%
    if confidence_score > 0.7:
        # Display the class name and confidence score on the webcam image
        text = f"Class: {class_name.strip()} ({int(confidence_score * 100)}%)"
        
        # Put the text on the image (on the top-left corner)
        cv2.putText(image, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Show the image with the prediction if confidence is greater than 70%
    cv2.imshow("Webcam Image", image)

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ...

# %%
from keras.models import load_model
from keras.layers import DepthwiseConv2D
import cv2  # Install opencv-python
import numpy as np
from gtts import gTTS  # Import gTTS for text-to-speech
import os
from playsound import playsound  # Import playsound for audio playback

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Custom DepthwiseConv2D to ignore the 'groups' argument if present
class CustomDepthwiseConv2D(DepthwiseConv2D):
    def __init__(self, *args, groups=1, **kwargs):
        super().__init__(*init_args, **kwargs)

# Load the model with custom object handling for DepthwiseConv2D
model = load_model("keras_Model.h5", custom_objects={'DepthwiseConv2D': CustomDepthwiseConv2D}, compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

# Define a function to speak the alphabet
def speak_alphabet(alphabet):
    tts = gTTS(text=alphabet, lang='en')
    tts.save("temp.mp3")  # Save the speech to a temporary file
    playsound("temp.mp3")  # Play the sound
    os.remove("temp.mp3")  # Remove the temporary file after playing

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height, 224-width) pixels
    image_resized = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Make the image a numpy array and reshape it to the model's input shape.
    image_array = np.asarray(image_resized, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image_array = (image_array / 127.5) - 1

    # Predict the model
    prediction = model.predict(image_array)
    index = np.argmax(prediction)
    class_name = class_names[index].strip()  # Get the recognized class name
    confidence_score = prediction[0][index]

    # Check if confidence score is greater than 70%
    if confidence_score > 0.7:
        # Display the class name and confidence score on the webcam image
        text = f"Class: {class_name} ({int(confidence_score * 100)}%)"
        
        # Put the text on the image (on the top-left corner)
        cv2.putText(image, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Speak the recognized alphabet
        speak_alphabet(class_name)

    # Show the image with the prediction if confidence is greater than 70%
    cv2.imshow("Webcam Image", image)

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\keras\src\ops\operation.py:234, in Operation.from_config(cls, config)
#     233 try:
# --> 234     return cls(**config)
#     235 except Exception as e:
#
# Cell In[5], line 15, in CustomDepthwiseConv2D.__init__(self, groups, *args, **kwargs)
#      14 def __init__(self, *args, groups=1, **kwargs):
# ---> 15     super().__init__(*init_args, **kwargs)
#
# NameError: name 'init_args' is not defined
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15         super().__init__(*init_args, **kwargs)
#      17 # Load the model with custom object handling for DepthwiseConv2D
# ...
